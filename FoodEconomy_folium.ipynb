# %% [markdown]
# <div style="padding:18px;border-width:5px;border-radius:10px;background:linear-gradient(to right, darkblue, red)">
# <h1 style="text-align:center; font-size:40px; font-weight:bold; color:white">Mapping Haiti’s Food Prices: A Geo-Spatial Analysis</h1>
# </div>

# %% [markdown]
# https://nbviewer.org/github/carl3991/Hands-On-Haiti/blob/main/FoodEconomy_folium.ipynb

# %% [markdown]
# ### Installing required libraries

# %%
# %pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -umpy (/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages)
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: folium in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (0.19.7)
# Requirement already satisfied: branca>=0.6.0 in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from requests->folium) (2024.2.2)
# WARNING: Ignoring invalid distribution -umpy (/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
from folium.plugins import MarkerCluster
from folium.plugins import MousePosition
from folium.features import DivIcon

# %%
# %pip install pandas numpy seaborn matplotlib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -umpy (/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages)
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: pandas in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: seaborn in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (3.9.3)
# Requirement already satisfied: scikit-learn in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.6.0 in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -umpy (/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/.local/lib/python3.10/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
print(os.getcwd())
# Out:
# /home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/My Projects/Haiti

# %%
# Loading the csv file
haiti_df = pd.read_csv("/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/My Projects/Haiti/cleaned_food_prices.csv")

# Show top 5 rows of dataset
print(haiti_df.head())
# Out:
#          date  Department      City    market  latitude  longitude  \
# 0  2005-01-15  Artibonite  Gonaives  Gonaives     19.45 -72.683333
# 1  2005-01-15  Artibonite  Gonaives  Gonaives     19.45 -72.683333
# 2  2005-01-15  Artibonite  Gonaives  Gonaives     19.45 -72.683333
# 3  2005-01-15      Centre    Hinche    Hinche     19.15 -72.016667
# 4  2005-01-15      Centre    Hinche    Hinche     19.15 -72.016667
#
#             food_type               commodity     unit  usdprice
# 0  cereals and tubers      Maize meal (local)  Marmite    0.4554
# 1  cereals and tubers           Rice (tchako)  Marmite    0.7135
# 2  cereals and tubers  Wheat flour (imported)  Marmite    0.4554
# 3  cereals and tubers   Maize meal (imported)    Pound    0.0999
# 4  cereals and tubers      Maize meal (local)  Marmite    0.2733

# %%
haiti_df.dtypes
# Out:
# date           object
# Department     object
# City           object
# market         object
# latitude      float64
# longitude     float64
# food_type      object
# commodity      object
# unit           object
# usdprice      float64
# dtype: object

# %%
# converting features properly
haiti_df['date'] = pd.to_datetime(haiti_df['date'])

cat_feat = ['commodity', 'Department', 'City', 'market', 'food_type', 'unit']
haiti_df[cat_feat] = haiti_df[cat_feat].astype('category')

# %%
haiti_df.dtypes
# Out:
# date          datetime64[ns]
# Department          category
# City                category
# market              category
# latitude             float64
# longitude            float64
# food_type           category
# commodity           category
# unit                category
# usdprice             float64
# dtype: object

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# #  Data Wrangling for the Map

# %%
# Creating the median price per department
haiti_df2 = haiti_df[['usdprice','commodity','Department','latitude','longitude']]
median_prices = haiti_df2.groupby('Department')['usdprice'].median().reset_index()

# Sorting the median prices
median_prices = median_prices.sort_values(by='usdprice', ascending=False)
print(median_prices)
# Out:
#     Department  usdprice
# 0   Artibonite    2.8464
# 5   North-West    2.5979
# 4   North-East    1.7929
# 3        North    1.7835
# 6        South    1.6104
# 7   South-East    1.5940
# 1       Centre    1.5203
# 2  Grande'Anse    1.3670
# 8         West    1.3283
# /tmp/ipykernel_1854/956165228.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   median_prices = haiti_df2.groupby('Department')['usdprice'].median().reset_index()

# %%
# Creating coordinates for the 9 departments in the dataset
dept_coords = {
    'Artibonite': [19.45, -72.683333],
    'Centre':[19.15, -72.016667] ,
    "Grande'Anse":[18.616667, -74.083333] ,
    'North': [19.757778, -72.204167],
    'North-East':[19.55, -71.733333] ,
    'North-West':[19.939051, -72.8319] ,
    'South': [18.2, -73.75],
    'South-East': [18.234167, -72.534722],
    'West': [18.539167, -72.335]
}

# %%
# Converting the coordinates to a dataframe
coord_df = pd.DataFrame([
    {'Department': k, 'latitude': v[0], 'longitude': v[1]} 
    for k, v in dept_coords.items()
])

# %%
# Merging the median prices and the coordinates
map_df = pd.merge(median_prices, coord_df, on='Department')
map_df
# Out:
#     Department  usdprice   latitude  longitude
# 0   Artibonite    2.8464  19.450000 -72.683333
# 1   North-West    2.5979  19.939051 -72.831900
# 2   North-East    1.7929  19.550000 -71.733333
# 3        North    1.7835  19.757778 -72.204167
# 4        South    1.6104  18.200000 -73.750000
# 5   South-East    1.5940  18.234167 -72.534722
# 6       Centre    1.5203  19.150000 -72.016667
# 7  Grande'Anse    1.3670  18.616667 -74.083333
# 8         West    1.3283  18.539167 -72.335000

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# ## Visualizing the Median Prices per Department

# %%
# Generating the map
haiti_map = folium.Map()

# Adding markers
for _,row in map_df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=row['usdprice'] *5,
        color='crimson',
        fill=True,
        fill_color='orange',
        fill_opacity=0.7,
        popup=folium.Popup(f"{row['Department']}: ${row['usdprice']:.2f}", max_width=250)
    ).add_to(haiti_map)
    
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_901419170be56759f4ba878703ff71d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_901419170be56759f4ba878703ff71d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_901419170be56759f4ba878703ff71d5 = L.map(
#                 &quot;map_901419170be56759f4ba878703ff71d5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2fce57197027d6c84b9abc9df65849a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2fce57197027d6c84b9abc9df65849a.addTo(map_901419170be56759f4ba878703ff71d5);
#
#
#             var circle_marker_00fed2784a087cfd72fae1eebe2cd2ea = L.circleMarker(
#                 [19.45, -72.683333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.232, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_901419170be56759f4ba878703ff71d5);
#
#
#         var popup_daa1ab95b5d96156da0bcc7635575de6 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_22dc753d3c2e84c65799e27c046039eb = $(`&lt;div id=&quot;html_22dc753d3c2e84c65799e27c046039eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Artibonite: $2.85&lt;/div&gt;`)[0];
#                 popup_daa1ab95b5d96156da0bcc7635575de6.setContent(html_22dc753d3c2e84c65799e27c046039eb);
#
#
#
#         circle_marker_00fed2784a087cfd72fae1eebe2cd2ea.bindPopup(popup_daa1ab95b5d96156da0bcc7635575de6)
#         ;
#
#
#
#
#             var circle_marker_d5ce70eb9f44754525e36819a8300ff7 = L.circleMarker(
#                 [19.939051, -72.8319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.9895, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_901419170be56759f4ba878703ff71d5);
#
#
#         var popup_6c1204cf1a1454a2a06464419a66564f = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_3c460622d7604b081dd057f694fbfc67 = $(`&lt;div id=&quot;html_3c460622d7604b081dd057f694fbfc67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-West: $2.60&lt;/div&gt;`)[0];
#                 popup_6c1204cf1a1454a2a06464419a66564f.setContent(html_3c460622d7604b081dd057f694fbfc67);
#
#
#
#         circle_marker_d5ce70eb9f44754525e36819a8300ff7.bindPopup(popup_6c1204cf1a1454a2a06464419a66564f)
#         ;
#
#
#
#
#             var circle_marker_1c649d285b5a9cd941c4f5d707b20854 = L.circleMarker(
#                 [19.55, -71.733333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.9645, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_901419170be56759f4ba878703ff71d5);
#
#
#         var popup_1dd7fd94a98cbc022c6760d63c56c27a = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_2f1442c3077150c9a0182f724b355d4f = $(`&lt;div id=&quot;html_2f1442c3077150c9a0182f724b355d4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-East: $1.79&lt;/div&gt;`)[0];
#                 popup_1dd7fd94a98cbc022c6760d63c56c27a.setContent(html_2f1442c3077150c9a0182f724b355d4f);
#
#
#
#         circle_marker_1c649d285b5a9cd941c4f5d707b20854.bindPopup(popup_1dd7fd94a98cbc022c6760d63c56c27a)
#         ;
#
#
#
#
#             var circle_marker_ea20d15e58f4253b4ecca4dccfa11a8b = L.circleMarker(

# %% [markdown]
# The display is not what I was hoping for. I wanted it to show Haiti with the markers directly without having to zoom in manually. Here's the solution to this...

# %%
# Generic map
haiti_map = folium.Map()

#Adding the markers
for _, row in median_prices.iterrows():
    all_coord = dept_coords.get(row['Department'])
    if all_coord:
        folium.CircleMarker(
            location=all_coord,
            radius=row['usdprice'] * 10,
            fill= True,
            fill_color='blue',
            fill_opacity=0.6,
            popup= folium.Popup(f"{row['Department']}: ${row['usdprice']:.2f}", max_width= 350)
            
        ).add_to(haiti_map)
MousePosition().add_to(haiti_map)

# Adjusting the map view to fit all markers with fit_bounds
haiti_map.fit_bounds(list(dept_coords.values()))
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb6d58b7d594af8339648afa003b5a8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb6d58b7d594af8339648afa003b5a8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb6d58b7d594af8339648afa003b5a8b = L.map(
#                 &quot;map_cb6d58b7d594af8339648afa003b5a8b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_039c3724e65881abdb2ec9bef3109cfd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_039c3724e65881abdb2ec9bef3109cfd.addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#             var circle_marker_25ed95df429c356a49710e729e6a362b = L.circleMarker(
#                 [19.45, -72.683333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.464, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#         var popup_6766406dd9d1175917827461137bff4a = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_e54891ee65c839a540d39618e4db3790 = $(`&lt;div id=&quot;html_e54891ee65c839a540d39618e4db3790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Artibonite: $2.85&lt;/div&gt;`)[0];
#                 popup_6766406dd9d1175917827461137bff4a.setContent(html_e54891ee65c839a540d39618e4db3790);
#
#
#
#         circle_marker_25ed95df429c356a49710e729e6a362b.bindPopup(popup_6766406dd9d1175917827461137bff4a)
#         ;
#
#
#
#
#             var circle_marker_66ef195e0896374b55e560815453eede = L.circleMarker(
#                 [19.939051, -72.8319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.979, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#         var popup_81b0b949d13bd9cbf3f1d1113882443d = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_5aba2cc50d390e639dadb3ff3e20310b = $(`&lt;div id=&quot;html_5aba2cc50d390e639dadb3ff3e20310b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-West: $2.60&lt;/div&gt;`)[0];
#                 popup_81b0b949d13bd9cbf3f1d1113882443d.setContent(html_5aba2cc50d390e639dadb3ff3e20310b);
#
#
#
#         circle_marker_66ef195e0896374b55e560815453eede.bindPopup(popup_81b0b949d13bd9cbf3f1d1113882443d)
#         ;
#
#
#
#
#             var circle_marker_dca514579cc7d825758811548c6871b4 = L.circleMarker(
#                 [19.55, -71.733333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.929, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#         var popup_005e9889f43c3a2744b43a90ed361b31 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_435a03e537a2f34607d3d45e3bc0fa3b = $(`&lt;div id=&quot;html_435a03e537a2f34607d3d45e3bc0fa3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-East: $1.79&lt;/div&gt;`)[0];
#                 popup_005e9889f43c3a2744b43a90ed361b31.setContent(htm

# %% [markdown]
# Much better!

# %% [markdown]
# ### Comments:

# %% [markdown]
# The standout prices of 2.85 dollars in Artibonite and 2.60 dollars in North-West on signal unique supply chain challenges or market inefficiencies. Further investigation is needed for and **commodity concentration** and the **distribution networks (imported vs local)**.

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# # Commodity Concentration

# %% [markdown]
# We'll investigate for the first two department with highest median prices.

# %% [markdown]
# ### For Artibonite

# %%
# Filtering Artibonite again
artibonite_df = haiti_df[haiti_df['Department'] == 'Artibonite']

# Total number of rows for Artibonite
total_count = len(artibonite_df)

# Number of rows for the top 2 commodities
top_2_commodities = artibonite_df['commodity'].value_counts().head(2).index.tolist()
top_2_count = artibonite_df[artibonite_df['commodity'].isin(top_2_commodities)].shape[0]

# Calculating proportion
weight = top_2_count / total_count

print(f"Top 2 commodities account for {weight:.2%} of North West listings.")
# Out:
# Top 2 commodities account for 32.23% of North West listings.

# %% [markdown]
# ### For North-West

# %%
# Filtering North-West
north_west_df = haiti_df[haiti_df['Department'] == 'North-West']

# Total number of rows for North-West
total_count2 = len(north_west_df)

# Number of rows for just the top 2 commodities
top_2_commodities2 = north_west_df['commodity'].value_counts().head(2).index.tolist()
top_2_count2 = north_west_df[north_west_df['commodity'].isin(top_2_commodities2)].shape[0]

# Calculating proportion
weight = top_2_count2 / total_count2

print(f"Top 2 commodities account for {weight:.2%} of North-West listings.")
# Out:
# Top 2 commodities account for 36.36% of North-West listings.

# %% [markdown]
# #### Let's represent the weights visually.

# %%
# Weight dictionary
weights = {'Artibonite': 0.3223, 'North-West': 0.3636}


# Loop through weights to create CircleMarkers
for dept, weight in weights.items():
    coords = dept_coords[dept]
    folium.CircleMarker(
        location=coords,
        radius=weight * 50,  
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.9,
        popup=f"{dept}: Top 2 commodities represent {weight:.2%}"
    ).add_to(haiti_map)
MousePosition().add_to(haiti_map)
    
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb6d58b7d594af8339648afa003b5a8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb6d58b7d594af8339648afa003b5a8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb6d58b7d594af8339648afa003b5a8b = L.map(
#                 &quot;map_cb6d58b7d594af8339648afa003b5a8b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_039c3724e65881abdb2ec9bef3109cfd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_039c3724e65881abdb2ec9bef3109cfd.addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#             var circle_marker_25ed95df429c356a49710e729e6a362b = L.circleMarker(
#                 [19.45, -72.683333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.464, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#         var popup_6766406dd9d1175917827461137bff4a = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_e54891ee65c839a540d39618e4db3790 = $(`&lt;div id=&quot;html_e54891ee65c839a540d39618e4db3790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Artibonite: $2.85&lt;/div&gt;`)[0];
#                 popup_6766406dd9d1175917827461137bff4a.setContent(html_e54891ee65c839a540d39618e4db3790);
#
#
#
#         circle_marker_25ed95df429c356a49710e729e6a362b.bindPopup(popup_6766406dd9d1175917827461137bff4a)
#         ;
#
#
#
#
#             var circle_marker_66ef195e0896374b55e560815453eede = L.circleMarker(
#                 [19.939051, -72.8319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.979, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#         var popup_81b0b949d13bd9cbf3f1d1113882443d = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_5aba2cc50d390e639dadb3ff3e20310b = $(`&lt;div id=&quot;html_5aba2cc50d390e639dadb3ff3e20310b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-West: $2.60&lt;/div&gt;`)[0];
#                 popup_81b0b949d13bd9cbf3f1d1113882443d.setContent(html_5aba2cc50d390e639dadb3ff3e20310b);
#
#
#
#         circle_marker_66ef195e0896374b55e560815453eede.bindPopup(popup_81b0b949d13bd9cbf3f1d1113882443d)
#         ;
#
#
#
#
#             var circle_marker_dca514579cc7d825758811548c6871b4 = L.circleMarker(
#                 [19.55, -71.733333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.929, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb6d58b7d594af8339648afa003b5a8b);
#
#
#         var popup_005e9889f43c3a2744b43a90ed361b31 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_435a03e537a2f34607d3d45e3bc0fa3b = $(`&lt;div id=&quot;html_435a03e537a2f34607d3d45e3bc0fa3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-East: $1.79&lt;/div&gt;`)[0];
#                 popup_005e9889f43c3a2744b43a90ed361b31.setContent(htm

# %% [markdown]
# ### Comments:

# %% [markdown]
# 32.23% and 36.36% tell us that market activity in both Artibonite and North-West is concentrated in two commodities, representing approximately one-third of all staple goods consumed. Therefore, the high price levels in these region may reflect not just inflationary pressure, but a narrow set of frequently traded goods.

# %% [markdown]
# ### Implications

# %% [markdown]
# 1. **Market Dependence**: A heavy reliance on two goods suggests a vulnerability to price shocks if supply is disrupted.
#
# 2. **Reduced Economic Diversity:** If a region’s markets trade in just a couple of goods, it can signal *limited access to alternative food options*.
#
# 3. **Price Volatility Risk:** When a large portion of transactions centers around two commodities, any disruption *(import delays or inflation)* can cause large price swings, dragging the entire food market’s price median upward.
#
# 4. **Aid Policy Programs:** Food subsidies in Artibonite and North-West might be more effective if they target those dominant commodities *(Wheat flour and Maaize meal)*.

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# # Choropleth

# %%
import json

# json file location
geojson_path = "/home/af2ea8f5-1f9a-4091-9c13-db2b59ea1801/My Projects/Haiti/ht.json"

# Load the GeoJSON file
with open(geojson_path, "r", encoding="utf-8") as f:
    world_geo = json.load(f)

# %%
# Making sure the Department names are the same
geo_names = [feature['properties']['name'] for feature in world_geo['features']]
df_names = median_prices['Department'].unique()

print("Names in JSON but not in DataFrame:", set(geo_names) - set(df_names))
print("Names in DataFrame but not in JSON:", set(df_names) - set(geo_names))
# Out:
# Names in JSON but not in DataFrame: {'Nord', 'Nord-Est', 'Nippes', "Grand'Anse", 'Ouest', 'Sud', 'Sud-Est', 'Nord-Ouest', "L'Artibonite"}
# Names in DataFrame but not in JSON: {'West', "Grande'Anse", 'Artibonite', 'South', 'North-West', 'North', 'South-East', 'North-East'}

# %%
# Department name mapping (in french for the GeoJSON file)
name_mapping = {
    'North-West': 'Nord-Ouest',
    'North-East': 'Nord-Est',
    'South': 'Sud',
    'South-East': 'Sud-Est',
    'West': 'Ouest',
    'Artibonite': "L'Artibonite",
    'North': 'Nord',
    "Grande'Anse": "Grand'Anse"
}

# %%
# Making a copy just to be safe
median_prices_cleaned = median_prices.copy()

# Apply the name translation in the copied dataset median_price_cleaned
median_prices_cleaned['Department'] = median_prices_cleaned['Department'].replace(name_mapping)
# Out:
# /tmp/ipykernel_1854/903628318.py:5: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   median_prices_cleaned['Department'] = median_prices_cleaned['Department'].replace(name_mapping)

# %%
# Create the base map
haiti_map = folium.Map(location=[19.0, -72.7], zoom_start=8)

# Add Choropleth 
folium.Choropleth(
    geo_data=world_geo,
    data=median_prices_cleaned,
    columns=['Department', 'usdprice'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Median Prices per Department',
    highlight=True
).add_to(haiti_map)

# Display the map
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f8406faa2dd5dc9ba942a693fb407f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f8406faa2dd5dc9ba942a693fb407f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f8406faa2dd5dc9ba942a693fb407f2 = L.map(
#                 &quot;map_7f8406faa2dd5dc9ba942a693fb407f2&quot;,
#                 {
#                     center: [19.0, -72.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61bd5e5c7795bb4d4e113cea89df4066 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61bd5e5c7795bb4d4e113cea89df4066.addTo(map_7f8406faa2dd5dc9ba942a693fb407f2);
#
#
#             var choropleth_49263cc60fe0186d03e1f932160f50e5 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_styler(feature) {
#             switch(feature.id) {
#                 case 1: case 4: case 5: case 8:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 2: case 3: case 6:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 7: case 9:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8 = L.geoJson(null, {
#                 onEachFeature: geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_onEachFeature,
#
#                 style: geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_styler,
#             ...{
# }
#         });
#
#         function geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_add (data) {
#             geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8
#                 .addData(data);
#         }
#             geo_json_6506eca4c6fc349ef994b0ca7a1ee7f8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.74951706694361, 19.27970763938768], [-71.74998184481255, 19.279650258208903], [-71.78390741896786, 19.275464436325066], [-71.81925411135671, 19.278358430615633], [-71.83765093161487, 19.27711827611142], [-71.8604402429906, 19.28125242482786], [-71.88762205396026, 19.284869842376562], [-71.906225562048, 19.29975259566831], [-71.94327754831978, 19.31577215476862], [-71.97888259854687, 19.335770838795], [-71.99552243948241, 19.38734416104704], [-72.04595861515861, 19.43576480217938], [-72.06461380234562, 19.440932405080883], [-72.08301061127449, 19.44568662355243], [-72.07308876446206, 19.460414635178378], [-72.06998818361521, 19.4869246901861], [-72.087041377843, 19.51296938089092], [-72.09727332665811, 19.542528427731607], [-72.11073502816285, 19.566144474809334], [-72.11370641243398, 19.58965717031016], [-72.10977900900986, 19.60236961553349], [-72.11050247582875, 19.616115517741868], [-72.09838436327117, 19.623660366394333], [-72.0823388405563, 19.626864388310416], [-72.06099648547946, 19.65652674647723], [-72.0565264453309

# %% [markdown]
# The Department whith color black is likely a department that exists in the GeoJSON but doesn't have a matching entry in the median_prices_cleaned dataset. Folium renders unmatched polygons in black when no value is found. Here's a way to fix this...

# %%
geo_names = [feature['properties']['name'] for feature in world_geo['features']]
df_names = median_prices_cleaned['Department'].tolist()

# Checking unmatched Department
unmatched = set(geo_names) - set(df_names)
print("Departments in GeoJSON but not in DataFrame:", unmatched)
# Out:
# Departments in GeoJSON but not in DataFrame: {'Nippes'}

# %% [markdown]
# **`Nippes` is the unmatched department.**

# %% [markdown]
# Let's assign an estimated value for `Nippes` with the overall median of all department.

# %%
# Overall median prices
overall_median = median_prices_cleaned['usdprice'].median()
median_prices_cleaned.loc[len(median_prices_cleaned)] = ['Nippes', overall_median]
print('The overall median price for the availbale departments is:','$',overall_median)
# Out:
# The overall median price for the availbale departments is: $ 1.6104

# %% [markdown]
# Now `Nippes` is assigned the value of 1.6104 us dollars<br> </br>
# Let's visualize the Choropleth again.

# %%
# Create the base map
haiti_map = folium.Map(location=[19.0, -72.7], zoom_start=8)

# Add Choropleth 
folium.Choropleth(
    geo_data=world_geo,
    data=median_prices_cleaned,
    columns=['Department', 'usdprice'],
    key_on='feature.properties.name',
    fill_color='plasma',
    fill_opacity=0.45,
    line_opacity=0.5,
    legend_name='Median Prices per Department',
    highlight=True
).add_to(haiti_map)
MousePosition().add_to(haiti_map)

# Highlighting the 2 High price areas
locs = [19.50853,-73.23007 ] #location to to include the DivIcon text
folium.Marker(
        location=locs,
        icon=DivIcon(html="<div style='font-size:25px; font-weight:bold;color:black;'> High Price Zone</div>")
        ).add_to(haiti_map)
# Display the map
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc8abf12a348e35e46477eb64b7af71d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc8abf12a348e35e46477eb64b7af71d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc8abf12a348e35e46477eb64b7af71d = L.map(
#                 &quot;map_fc8abf12a348e35e46477eb64b7af71d&quot;,
#                 {
#                     center: [19.0, -72.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2180ca220f73e611cca65c2138c4787c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2180ca220f73e611cca65c2138c4787c.addTo(map_fc8abf12a348e35e46477eb64b7af71d);
#
#
#             var choropleth_ac71e0fb402eefb16b0ac7c91b7d50d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_3feae2b2486a35f0065287d71b147871_styler(feature) {
#             switch(feature.id) {
#                 case 1: case 4: case 5: case 8: case 10:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6900a7&quot;, &quot;fillOpacity&quot;: 0.45, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case 2: case 3: case 6:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#0d0887&quot;, &quot;fillOpacity&quot;: 0.45, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f0f921&quot;, &quot;fillOpacity&quot;: 0.45, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_3feae2b2486a35f0065287d71b147871_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.65, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_3feae2b2486a35f0065287d71b147871_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3feae2b2486a35f0065287d71b147871.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3feae2b2486a35f0065287d71b147871_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3feae2b2486a35f0065287d71b147871 = L.geoJson(null, {
#                 onEachFeature: geo_json_3feae2b2486a35f0065287d71b147871_onEachFeature,
#
#                 style: geo_json_3feae2b2486a35f0065287d71b147871_styler,
#             ...{
# }
#         });
#
#         function geo_json_3feae2b2486a35f0065287d71b147871_add (data) {
#             geo_json_3feae2b2486a35f0065287d71b147871
#                 .addData(data);
#         }
#             geo_json_3feae2b2486a35f0065287d71b147871_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.74951706694361, 19.27970763938768], [-71.74998184481255, 19.279650258208903], [-71.78390741896786, 19.275464436325066], [-71.81925411135671, 19.278358430615633], [-71.83765093161487, 19.27711827611142], [-71.8604402429906, 19.28125242482786], [-71.88762205396026, 19.284869842376562], [-71.906225562048, 19.29975259566831], [-71.94327754831978, 19.31577215476862], [-71.97888259854687, 19.335770838795], [-71.99552243948241, 19.38734416104704], [-72.04595861515861, 19.43576480217938], [-72.06461380234562, 19.440932405080883], [-72.08301061127449, 19.44568662355243], [-72.07308876446206, 19.460414635178378], [-72.06998818361521, 19.4869246901861], [-72.087041377843, 19.51296938089092], [-72.09727332665811, 19.542528427731607], [-72.11073502816285, 19.566144474809334], [-72.11370641243398, 19.58965717031016], [-72.10977900900986, 19.60236961553349], [-72.11050247582875, 19.616115517741868], [-72.09838436327117, 19.623660366394333], [-72.0823388405563, 19.62686

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# <div style="border:2px solid black; padding=:15px; background-color:#f4f4f4;">
# <h1 style="text-align:center; font-size:26px">Summary</h1>
# <p style="text-align:center; font-size:20px">  Haiti’s food markets show significant disparities. Artibonite and North-West region have the highest median prices and heavy reliance on two commodities. TThis uneven distribution shows that some regions have limited access to food, depend heavily on just a few products, and face unstable prices.</p>
# <hr style="border:2px red; background-color: white">
# <h3 style="text-align:center;"> Presented by:
# <a href="https://www.linkedin.com/in/carllegros/" target="_blank" style="color:blue;"> Carl Legros </a>
# </h3>
# </div>
