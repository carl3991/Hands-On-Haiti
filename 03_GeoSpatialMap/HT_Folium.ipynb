# %% [markdown]
# <div style="
#     background: linear-gradient(90deg, #c8102e 0%, #002868 100%);
#     color: white;
#     padding: 18px 22px;
#     border-left: 6px solid #002868;
#     border-right: 6px solid #c8102e;
#     border-top: 3px solid #002868;
#     border-bottom: 3px solid #002868;
#     border-radius: 8px;
#     box-shadow: 0 2px 8px rgba(0,0,0,0.18);
#     font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, sans-serif;
# ">
#
#   <h1 style="
#       margin: 0 0 6px 0;
#       font-size: 30px;
#       font-weight: 700;
#       letter-spacing: 0.03em;
#       text-transform: uppercase;
#       color: white;
#   ">
#     Mapping Haiti's Food Prices: A Geo-Spatial Analysis
#
#   </h1>
# </div>

# %% [markdown]
# <br></br>

# %%
# Install folium
# %pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2025.11.12)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import folium
from folium.plugins import MarkerCluster
from folium.plugins import MousePosition
from folium.features import DivIcon
import json
import requests

# %%
# Load dataset
file_id = "1VyLHX20ofimGB7jhFhhw06MBu9Ajod4o"
url = f"https://drive.google.com/uc?download&id={file_id}"
haiti_df = pd.read_csv(url)
print(haiti_df.head())
# Out:
#          date  Department      City    market  latitude  longitude  \
# 0  2005-01-15  Artibonite  Gonaives  Gonaives     19.45 -72.683333
# 1  2005-01-15  Artibonite  Gonaives  Gonaives     19.45 -72.683333
# 2  2005-01-15  Artibonite  Gonaives  Gonaives     19.45 -72.683333
# 3  2005-01-15      Centre    Hinche    Hinche     19.15 -72.016667
# 4  2005-01-15      Centre    Hinche    Hinche     19.15 -72.016667
#
#             food_type               commodity     unit  usdprice
# 0  cereals and tubers      Maize meal (local)  Marmite    0.4554
# 1  cereals and tubers           Rice (tchako)  Marmite    0.7135
# 2  cereals and tubers  Wheat flour (imported)  Marmite    0.4554
# 3  cereals and tubers   Maize meal (imported)    Pound    0.0999
# 4  cereals and tubers      Maize meal (local)  Marmite    0.2733

# %%
# Data types
haiti_df.dtypes
# Out:
# date           object
# Department     object
# City           object
# market         object
# latitude      float64
# longitude     float64
# food_type      object
# commodity      object
# unit           object
# usdprice      float64
# dtype: object

# %%
# Convert date feature
haiti_df['date'] = pd.to_datetime(haiti_df['date'])

# %%
# Data types check
haiti_df.dtypes
# Out:
# date          datetime64[ns]
# Department            object
# City                  object
# market                object
# latitude             float64
# longitude            float64
# food_type             object
# commodity             object
# unit                  object
# usdprice             float64
# dtype: object

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# #  **Data Preprocessing**

# %%
# Creating the median price per department
haiti_df2 = haiti_df[['usdprice','commodity','Department','latitude','longitude']]
median_prices = haiti_df2.groupby('Department')['usdprice'].median().reset_index()

# Sorting the median prices
median_prices = median_prices.sort_values(by='usdprice', ascending=False)
print(median_prices)
# Out:
#     Department  usdprice
# 0   Artibonite    2.8464
# 5   North-West    2.5979
# 4   North-East    1.7929
# 3        North    1.7835
# 6        South    1.6104
# 7   South-East    1.5940
# 1       Centre    1.5203
# 2  Grande'Anse    1.3670
# 8         West    1.3283

# %%
# Create coordinates for the 9 departments in the dataset
dept_coords = {
    'Artibonite': [19.45, -72.683333],
    'Centre':[19.15, -72.016667] ,
    "Grande'Anse":[18.616667, -74.083333] ,
    'North': [19.757778, -72.204167],
    'North-East':[19.55, -71.733333] ,
    'North-West':[19.939051, -72.8319] ,
    'South': [18.2, -73.75],
    'South-East': [18.234167, -72.534722],
    'West': [18.539167, -72.335]
}

# %%
# Convert the coordinates to a dataframe
coord_df = pd.DataFrame([
    {'Department': k, 'latitude': v[0], 'longitude': v[1]}
    for k, v in dept_coords.items()
])

# %%
# Merge median prices and the coordinates
map_df = pd.merge(median_prices, coord_df, on='Department')
map_df
# Out:
#     Department  usdprice   latitude  longitude
# 0   Artibonite    2.8464  19.450000 -72.683333
# 1   North-West    2.5979  19.939051 -72.831900
# 2   North-East    1.7929  19.550000 -71.733333
# 3        North    1.7835  19.757778 -72.204167
# 4        South    1.6104  18.200000 -73.750000
# 5   South-East    1.5940  18.234167 -72.534722
# 6       Centre    1.5203  19.150000 -72.016667
# 7  Grande'Anse    1.3670  18.616667 -74.083333
# 8         West    1.3283  18.539167 -72.335000

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# # **Map**

# %%
# Generic map
haiti_map = folium.Map()

# Add the markers
for _, row in median_prices.iterrows():
    all_coord = dept_coords.get(row['Department'])
    if all_coord:
        folium.CircleMarker(
            location=all_coord,
            radius=row['usdprice'] * 10,
            fill= True,
            fill_color='blue',
            fill_opacity=0.6,
            popup= folium.Popup(f"{row['Department']}: ${row['usdprice']:.2f}", max_width= 350)

        ).add_to(haiti_map)
MousePosition().add_to(haiti_map)

# Adjust the map view to fit all markers with fit_bounds
haiti_map.fit_bounds(list(dept_coords.values()))
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0410147b758c915dcc1543f05fd69147 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0410147b758c915dcc1543f05fd69147&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0410147b758c915dcc1543f05fd69147 = L.map(
#                 &quot;map_0410147b758c915dcc1543f05fd69147&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ed077d968eec246a4a34886cea77e0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ed077d968eec246a4a34886cea77e0f.addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#             var circle_marker_e8b183062112c97b6226e67db5407a4d = L.circleMarker(
#                 [19.45, -72.683333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.464, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#         var popup_a26f26d36d512fb132716a323fc5c475 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_8bfde8be8809f517f6997c0019c180e5 = $(`&lt;div id=&quot;html_8bfde8be8809f517f6997c0019c180e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Artibonite: $2.85&lt;/div&gt;`)[0];
#                 popup_a26f26d36d512fb132716a323fc5c475.setContent(html_8bfde8be8809f517f6997c0019c180e5);
#
#
#
#         circle_marker_e8b183062112c97b6226e67db5407a4d.bindPopup(popup_a26f26d36d512fb132716a323fc5c475)
#         ;
#
#
#
#
#             var circle_marker_4023575e64d79dfa531e14dc6763ab8a = L.circleMarker(
#                 [19.939051, -72.8319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.979, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#         var popup_1bb16c62dde80908352028018fcc69b3 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_f6347f6cab79442ea87338f1032abc69 = $(`&lt;div id=&quot;html_f6347f6cab79442ea87338f1032abc69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-West: $2.60&lt;/div&gt;`)[0];
#                 popup_1bb16c62dde80908352028018fcc69b3.setContent(html_f6347f6cab79442ea87338f1032abc69);
#
#
#
#         circle_marker_4023575e64d79dfa531e14dc6763ab8a.bindPopup(popup_1bb16c62dde80908352028018fcc69b3)
#         ;
#
#
#
#
#             var circle_marker_95d94cc7d5ae927aa4999c22a201a8b1 = L.circleMarker(
#                 [19.55, -71.733333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.929, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#         var popup_fe41923c9a112d8c9553ff1931217a43 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_627261ac98610f19063ee40867b77a8e = $(`&lt;div id=&quot;html_627261ac98610f19063ee40867b77a8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-East: $1.79&lt;/div&gt;`)[0];
#                 popup_fe41923c9a112d8c9553ff1931217a43.setContent(htm

# %% [markdown]
# ### Comment:

# %% [markdown]
# The standout prices of 2.85 dollars in Artibonite and 2.60 dollars in North-West on signal unique supply chain challenges or market inefficiencies.

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# # Commodity Concentration

# %% [markdown]
# We'll investigate for the first two department with highest median prices.

# %% [markdown]
# ### For Artibonite

# %%
# Filter Artibonite
artibonite_df = haiti_df[haiti_df['Department'] == 'Artibonite']

# Total number of rows for Artibonite
total_count = len(artibonite_df)

# Number of rows for the top 2 commodities
top_2_commodities = artibonite_df['commodity'].value_counts().head(2).index.tolist()
top_2_count = artibonite_df[artibonite_df['commodity'].isin(top_2_commodities)].shape[0]

# Calculate proportion
weight = top_2_count / total_count

print(f"Top 2 commodities account for {weight:.2%} of North West listings.")
# Out:
# Top 2 commodities account for 32.23% of North West listings.

# %% [markdown]
# ### For North-West

# %%
# Filter North-West
north_west_df = haiti_df[haiti_df['Department'] == 'North-West']

# Total number of rows for North-West
total_count2 = len(north_west_df)

# Number of rows for just the top 2 commodities
top_2_commodities2 = north_west_df['commodity'].value_counts().head(2).index.tolist()
top_2_count2 = north_west_df[north_west_df['commodity'].isin(top_2_commodities2)].shape[0]

# Calculate proportion
weight = top_2_count2 / total_count2

print(f"Top 2 commodities account for {weight:.2%} of North-West listings.")
# Out:
# Top 2 commodities account for 36.36% of North-West listings.

# %% [markdown]
# #### Let's represent the weights visually.

# %%
# Weight dictionary
weights = {'Artibonite': 0.3223, 'North-West': 0.3636}


# Loop through weights to create CircleMarkers
for dept, weight in weights.items():
    coords = dept_coords[dept]
    folium.CircleMarker(
        location=coords,
        radius=weight * 50,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.9,
        popup=f"{dept}: Top 2 commodities represent {weight:.2%}"
    ).add_to(haiti_map)
MousePosition().add_to(haiti_map)

haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0410147b758c915dcc1543f05fd69147 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0410147b758c915dcc1543f05fd69147&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0410147b758c915dcc1543f05fd69147 = L.map(
#                 &quot;map_0410147b758c915dcc1543f05fd69147&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ed077d968eec246a4a34886cea77e0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ed077d968eec246a4a34886cea77e0f.addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#             var circle_marker_e8b183062112c97b6226e67db5407a4d = L.circleMarker(
#                 [19.45, -72.683333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.464, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#         var popup_a26f26d36d512fb132716a323fc5c475 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_8bfde8be8809f517f6997c0019c180e5 = $(`&lt;div id=&quot;html_8bfde8be8809f517f6997c0019c180e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Artibonite: $2.85&lt;/div&gt;`)[0];
#                 popup_a26f26d36d512fb132716a323fc5c475.setContent(html_8bfde8be8809f517f6997c0019c180e5);
#
#
#
#         circle_marker_e8b183062112c97b6226e67db5407a4d.bindPopup(popup_a26f26d36d512fb132716a323fc5c475)
#         ;
#
#
#
#
#             var circle_marker_4023575e64d79dfa531e14dc6763ab8a = L.circleMarker(
#                 [19.939051, -72.8319],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.979, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#         var popup_1bb16c62dde80908352028018fcc69b3 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_f6347f6cab79442ea87338f1032abc69 = $(`&lt;div id=&quot;html_f6347f6cab79442ea87338f1032abc69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-West: $2.60&lt;/div&gt;`)[0];
#                 popup_1bb16c62dde80908352028018fcc69b3.setContent(html_f6347f6cab79442ea87338f1032abc69);
#
#
#
#         circle_marker_4023575e64d79dfa531e14dc6763ab8a.bindPopup(popup_1bb16c62dde80908352028018fcc69b3)
#         ;
#
#
#
#
#             var circle_marker_95d94cc7d5ae927aa4999c22a201a8b1 = L.circleMarker(
#                 [19.55, -71.733333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.929, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0410147b758c915dcc1543f05fd69147);
#
#
#         var popup_fe41923c9a112d8c9553ff1931217a43 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_627261ac98610f19063ee40867b77a8e = $(`&lt;div id=&quot;html_627261ac98610f19063ee40867b77a8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North-East: $1.79&lt;/div&gt;`)[0];
#                 popup_fe41923c9a112d8c9553ff1931217a43.setContent(htm

# %% [markdown]
# #### Comment:
# 32.23% and 36.36% show that both Artibonite and North‑West rely heavily on just two commodities, making up about one‑third of all staple food listings. **This concentration suggests that higher prices in these regions may come not only from inflation, but also from the fact that a small set of goods dominates both local trade and local consumption.**

# %% [markdown]
# <br></br>

# %% [markdown]
# ## What does this reveal for Haiti's food market dynamics?

# %% [markdown]
# 1. **Market Dependence**: A heavy reliance on two goods suggests a vulnerability to price shocks if supply is disrupted.
#
# 2. **Reduced Economic Diversity:** If a region's markets trade in just a couple of goods, it can signal limited access to alternative food options.
#
# 3. **Price Volatility Risk:** When a large portion of transactions centers around two commodities, any disruption *(import delays or inflation)* can cause large price swings, dragging the entire food market's price median upward.
#
# 4. **Aid Policy Programs:** Food subsidies in Artibonite and North-West might be more effective if they target those dominant commodities *(Wheat flour and Maize meal)*.

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# # **Choropleth**

# %%
# Load json file
file_id = "1REqI1qWXQoTdNtbiU7P22W8Vn5mvXnS6"
url = f"https://drive.google.com/uc?export=download&id={file_id}"

response = requests.get(url)
world_geo = response.json()

print("Loaded GeoJSON with", len(world_geo), "top-level keys")
# Out:
# Loaded GeoJSON with 2 top-level keys

# %%
# Making sure the Department names are the same
geo_names = [feature['properties']['name'] for feature in world_geo['features']]
df_names = median_prices['Department'].unique()

print("Names in JSON but not in DataFrame:", set(geo_names) - set(df_names))
print("Names in DataFrame but not in JSON:", set(df_names) - set(geo_names))
# Out:
# Names in JSON but not in DataFrame: {'Sud-Est', 'Nippes', 'Nord', "Grand'Anse", "L'Artibonite", 'Nord-Ouest', 'Ouest', 'Nord-Est', 'Sud'}
# Names in DataFrame but not in JSON: {'North', 'North-East', 'South', 'North-West', "Grande'Anse", 'West', 'Artibonite', 'South-East'}

# %%
# Department name mapping (in french for the GeoJSON file)
name_mapping = {
    'North-West': 'Nord-Ouest',
    'North-East': 'Nord-Est',
    'South': 'Sud',
    'South-East': 'Sud-Est',
    'West': 'Ouest',
    'Artibonite': "L'Artibonite",
    'North': 'Nord',
    "Grande'Anse": "Grand'Anse"}

# %%
# Copy original median prices dataframe
median_prices_cleaned = median_prices.copy()

# Apply the name translation in the copied dataset median_price_cleaned
median_prices_cleaned['Department'] = median_prices_cleaned['Department'].replace(name_mapping)

# %%
# Create the base map
haiti_map = folium.Map(location=[19.0, -72.7], zoom_start=9)

# Add Choropleth
folium.Choropleth(
    geo_data=world_geo,
    data=median_prices_cleaned,
    columns=['Department', 'usdprice'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Median Prices per Department',
    highlight=True
).add_to(haiti_map)

# Display the map
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cceecb136ce3e95f3d41cc9ec6c5872a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cceecb136ce3e95f3d41cc9ec6c5872a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cceecb136ce3e95f3d41cc9ec6c5872a = L.map(
#                 &quot;map_cceecb136ce3e95f3d41cc9ec6c5872a&quot;,
#                 {
#                     center: [19.0, -72.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bad7ac26beeb541ab47c10927f598195 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bad7ac26beeb541ab47c10927f598195.addTo(map_cceecb136ce3e95f3d41cc9ec6c5872a);
#
#
#             var choropleth_40d013df4db143f7b7905d502d47f99c = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_styler(feature) {
#             switch(feature.id) {
#                 case 1: case 4: case 5: case 8:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 2: case 3: case 6:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 7: case 9:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_c51cce2b15b2fc8aa79d74e36dab91d3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c51cce2b15b2fc8aa79d74e36dab91d3 = L.geoJson(null, {
#                 onEachFeature: geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_onEachFeature,
#
#                 style: geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_styler,
#             ...{
# }
#         });
#
#         function geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_add (data) {
#             geo_json_c51cce2b15b2fc8aa79d74e36dab91d3
#                 .addData(data);
#         }
#             geo_json_c51cce2b15b2fc8aa79d74e36dab91d3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.74951706694361, 19.27970763938768], [-71.74998184481255, 19.279650258208903], [-71.78390741896786, 19.275464436325066], [-71.81925411135671, 19.278358430615633], [-71.83765093161487, 19.27711827611142], [-71.8604402429906, 19.28125242482786], [-71.88762205396026, 19.284869842376562], [-71.906225562048, 19.29975259566831], [-71.94327754831978, 19.31577215476862], [-71.97888259854687, 19.335770838795], [-71.99552243948241, 19.38734416104704], [-72.04595861515861, 19.43576480217938], [-72.06461380234562, 19.440932405080883], [-72.08301061127449, 19.44568662355243], [-72.07308876446206, 19.460414635178378], [-72.06998818361521, 19.4869246901861], [-72.087041377843, 19.51296938089092], [-72.09727332665811, 19.542528427731607], [-72.11073502816285, 19.566144474809334], [-72.11370641243398, 19.58965717031016], [-72.10977900900986, 19.60236961553349], [-72.11050247582875, 19.616115517741868], [-72.09838436327117, 19.623660366394333], [-72.0823388405563, 19.626864388310416], [-72.06099648547946, 19.65652674647723], [-72.0565264453309

# %% [markdown]
# The black color Department is likely a department that exists in the GeoJSON but doesn't have a matching entry in the median_prices_cleaned dataset. **Folium renders unmatched figure in black when no value is found**. Here's a way to fix this...

# %%
# Department names in json file
geo_names = [feature['properties']['name'] for feature in world_geo['features']]

# Department names for original dataset
df_names = median_prices_cleaned['Department'].tolist()

# Find unmatched Department
unmatched = set(geo_names) - set(df_names)
print("Departments in GeoJSON but not in DataFrame:", unmatched)
# Out:
# Departments in GeoJSON but not in DataFrame: {'Nippes'}

# %% [markdown]
# **Nippes is the unmatched department.**

# %% [markdown]
# Let's assign an average medan price value for `Nippes` with the overall median of all department.

# %%
# Overall median prices for availble departments
overall_median = median_prices_cleaned['usdprice'].median()

# Assign overall median prices for Nippes department
median_prices_cleaned.loc[len(median_prices_cleaned)] = ['Nippes', overall_median]
print('The overall median price for Nippes is:','$',overall_median)
# Out:
# The overall median price for Nippes is: $ 1.6104

# %%
# Create the base map
haiti_map = folium.Map(location=[19.0, -72.7], zoom_start=9)

# Add Choropleth
folium.Choropleth(
    geo_data=world_geo,
    data=median_prices_cleaned,
    columns=['Department', 'usdprice'],
    key_on='feature.properties.name',
    fill_color='RdBu_r',
    fill_opacity=0.45,
    line_opacity=0.5,
    legend_name='Median Prices per Department',
    highlight=True
).add_to(haiti_map)
MousePosition().add_to(haiti_map)

# Highlight the top 2 high price zones
locs = [19.50853,-73.23007 ] #location to to include the DivIcon text
folium.Marker(
        location=locs,
        icon=DivIcon(html="<div style='font-size:29px; font-weight:bold;color:black;'> High Price Zone</div>")
        ).add_to(haiti_map)
# Display the map
haiti_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ff20246bcb6f7f83b3a248c9a969990 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ff20246bcb6f7f83b3a248c9a969990&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ff20246bcb6f7f83b3a248c9a969990 = L.map(
#                 &quot;map_8ff20246bcb6f7f83b3a248c9a969990&quot;,
#                 {
#                     center: [19.0, -72.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8367526386b6a34e4d2c6090fdded441 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8367526386b6a34e4d2c6090fdded441.addTo(map_8ff20246bcb6f7f83b3a248c9a969990);
#
#
#             var choropleth_fe88b7e454665b0fc5edb2ff7e4bfa58 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_485ddf4e1dc2740b3439728d07b49886_styler(feature) {
#             switch(feature.id) {
#                 case 1: case 4: case 5: case 8: case 10:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#67a9cf&quot;, &quot;fillOpacity&quot;: 0.45, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case 2: case 3: case 6:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2166ac&quot;, &quot;fillOpacity&quot;: 0.45, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b2182b&quot;, &quot;fillOpacity&quot;: 0.45, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_485ddf4e1dc2740b3439728d07b49886_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.65, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_485ddf4e1dc2740b3439728d07b49886_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_485ddf4e1dc2740b3439728d07b49886.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_485ddf4e1dc2740b3439728d07b49886_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_485ddf4e1dc2740b3439728d07b49886 = L.geoJson(null, {
#                 onEachFeature: geo_json_485ddf4e1dc2740b3439728d07b49886_onEachFeature,
#
#                 style: geo_json_485ddf4e1dc2740b3439728d07b49886_styler,
#             ...{
# }
#         });
#
#         function geo_json_485ddf4e1dc2740b3439728d07b49886_add (data) {
#             geo_json_485ddf4e1dc2740b3439728d07b49886
#                 .addData(data);
#         }
#             geo_json_485ddf4e1dc2740b3439728d07b49886_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.74951706694361, 19.27970763938768], [-71.74998184481255, 19.279650258208903], [-71.78390741896786, 19.275464436325066], [-71.81925411135671, 19.278358430615633], [-71.83765093161487, 19.27711827611142], [-71.8604402429906, 19.28125242482786], [-71.88762205396026, 19.284869842376562], [-71.906225562048, 19.29975259566831], [-71.94327754831978, 19.31577215476862], [-71.97888259854687, 19.335770838795], [-71.99552243948241, 19.38734416104704], [-72.04595861515861, 19.43576480217938], [-72.06461380234562, 19.440932405080883], [-72.08301061127449, 19.44568662355243], [-72.07308876446206, 19.460414635178378], [-72.06998818361521, 19.4869246901861], [-72.087041377843, 19.51296938089092], [-72.09727332665811, 19.542528427731607], [-72.11073502816285, 19.566144474809334], [-72.11370641243398, 19.58965717031016], [-72.10977900900986, 19.60236961553349], [-72.11050247582875, 19.616115517741868], [-72.09838436327117, 19.623660366394333], [-72.0823388405563, 19.62686

# %% [markdown]
# <hr style="background:linear-gradient(to right,blue,red)"> </hr>

# %% [markdown]
# #### Comment:
# It is noticeable that Haiti's food markets aren't equal across regions. **Artibonite and North‑West have the highest median prices and rely heavily on just two main commodities.** This means some areas have fewer food options, depend on a small set of products, and deal with more unstable prices.

# %% [markdown]
# <br></br>

# %% [markdown]
# ### Presented by:
# <a href="https://www.linkedin.com/in/carllegros/" target="_blank" style="color:blue;"> Carl Legros </a>
